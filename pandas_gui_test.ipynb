# %%
import pandas as pd
from pandasgui import show
from pandasgui.datasets import titanic
gui = show(titanic)
# Out:
# PandasGUI INFO — pandasgui.datasets — Saved https://raw.githubusercontent.com/adamerose/datasets/master/pokemon.csv to C:\Users\corks\AppData\Local\pandasgui\dataset_files
# PandasGUI INFO — pandasgui.datasets — Saved https://raw.githubusercontent.com/adamerose/datasets/master/car_crashes.csv to C:\Users\corks\AppData\Local\pandasgui\dataset_files
# PandasGUI INFO — pandasgui.datasets — Saved https://raw.githubusercontent.com/adamerose/datasets/master/iris.csv to C:\Users\corks\AppData\Local\pandasgui\dataset_files
# PandasGUI INFO — pandasgui.datasets — Saved https://raw.githubusercontent.com/adamerose/datasets/master/mpg.csv to C:\Users\corks\AppData\Local\pandasgui\dataset_files
# PandasGUI INFO — pandasgui.datasets — Saved https://raw.githubusercontent.com/adamerose/datasets/master/penguins.csv to C:\Users\corks\AppData\Local\pandasgui\dataset_files
# ...
